# %%
import spacy
from spacy import displacy

import re
import pandas as pd
from textacy import extract

from collections import defaultdict

# %%
nlp = spacy.load("en_core_web_md")

# %%
def convert_spelled_nums_to_digit(token):
    mappings = {
        'one' : 1,'two' : 2,'three' : 3,'four' : 4,'five' : 5,'six' : 6,'seven' : 7,'eight' : 8,'nine' : 9,'ten' : 10
    }

    if mappings.get(token) is not None:
        return mappings[token]
    else:
        return token

assert convert_spelled_nums_to_digit("one") == 1
assert convert_spelled_nums_to_digit("onet") == 'onet'

# %%
STOP_ENTS = ['WASH','PSS','GTC','PFA','NFI','IYCF']

# %%
f = 'Herat_Earthquake_Flash_Update_13Oct2023_FINAL.txt'
f = 'unrwa_gaza_sitrep_27_nov_10_2023_eng.txt'
f = 'Herat Earthquake_Flash Update #1_7Oct2023_FINAL.txt'
file = f'D://projects//_external_files//surveyor//{f}'

#df_entities[df_entities['sent_idx'] == idx]

with open(file) as f:
    text = f.read()
    
def string_preprocess(text):
    text = text.replace("\n"," ")
    text = text.replace("-","_") #replace so tokenization doesn't separate

    #turn 'four' into 4
    text = ' '.join([str(convert_spelled_nums_to_digit(t)) for t in text.split(" ")])


    # remove content in parentheses
    #processed_string = re.sub(r'\([^)]*\)', '', input_string)

    #remove all non alpha numeric and punctuation
    pattern = r'[^a-zA-Z0-9\s\,\.\?\!\-\(\)]'
    text = re.sub(pattern, '', text)

    pattern = r'(\d+)\s+million'
    text = re.sub(r'(\d+)\s+million', r'\1,000,000', text)

    
    #remove commas that serve as thousands separators
    #Hack... fix this so I don't have to run it 3x
    text = re.sub(r'(\d+),(\d+)', r'\1\2', text)
    text = re.sub(r'(\d+),(\d+)', r'\1\2', text)
    text = re.sub(r'(\d+),(\d+)', r'\1\2', text)

    text = text.replace("\s+","\s")

    return text
date_of_report = '2023-10-13'
source = 'UNOCHA'
text = string_preprocess(text)
full_doc = nlp(text)

def string_remove_parenthetical_content(text):
    # Use regular expression to remove content inside parentheses
    text = re.sub(r'\([^)]*\)', '', text)

    return text
    
non_parens_text = string_remove_parenthetical_content(text)

# %%
admin_info = "D:\\projects\\_external_files\\country_info\\afg_adminboundaries_tabulardata_2.xlsx"

def build_admin_reference(admin_info):
    admin_df = pd.read_excel(admin_info, sheet_name="ADM2")
    return admin_df

admin_df = build_admin_reference(admin_info)

admins = []
admins.extend(admin_df['ADM2_EN'].tolist())
admins.extend(admin_df['ADM1_EN'].tolist())
admins.extend(admin_df['ADM0_EN'].tolist())
admins = list(set(admins))
admins.append('Herat')
admin_dict = {}
for ele in admins:
    admin_dict[ele]=1

# %%
def build_base_dataframe(text, filename='', date_of_report='', source=''):
    string_sent = [s.strip() for s in text.split('.')]

    dataframe_data=[]
    i=0
    for s in string_sent:
        x = [date_of_report,source,filename,i,s]
        i+=1
        dataframe_data.append(x)

    

    df = pd.DataFrame(dataframe_data,columns=['report_date','source','filename','sent_idx','string_sentence'])
    df['spacy_doc'] = df['string_sentence'].apply(lambda x: nlp(x))
    df['lower_lemmas'] = df['spacy_doc'].apply(lambda x: [w.lemma_.lower() for w in x])
    
    df['string_sent_wo_parens'] = df['string_sentence'].apply(string_remove_parenthetical_content)
    df['spacy_wo_parens'] = df['string_sent_wo_parens'].apply(lambda x: nlp(x))
    df['wo_parens_lower_lemmas'] = df['spacy_wo_parens'].apply(lambda x: [w.lemma_.lower() for w in x])
        

    df['locations'] = df['spacy_doc'].apply(lambda doc: [e for e in doc.ents if e.label_ == 'GPE'])
    df['dates'] = df['spacy_doc'].apply(lambda doc: [e for e in doc.ents if e.label_ == 'DATE'])
    df['svot'] = df['spacy_wo_parens'].apply(lambda doc: list(extract.subject_verb_object_triples(doc)))

    

    return df

df = build_base_dataframe(text, filename=file, date_of_report=date_of_report, source=source)

# %%
#keyword_indicators
indicators = {
    'i_people' : ['people','person','child','man','woman']
    ,'i_civilian' : ['civilian']
    ,'i_killed' : ['dead','fatal','die','kill','deceased']
    ,'i_injured' : ['injure']
    ,'i_damage' : ['damage','destroy','collapse']
    ,'i_health_infrastructure' : ['hospital','surgery']
    ,'i_education_infrastructure' : ['school','university']
    ,'i_cash_xfer' : ['xx']
    ,'i_wash' : ['sanitation','water','sewer','drain','drainage']
    ,'i_shelter' : ['shelter','tent','camp','blanket']
    ,'i_food' : ['food','cook','stove','feed','feed','nutrient','meal']
    ,'i_health' : ['health','medical','medicine']
    ,'i_gender_vuln' : ['dignity','gender','pregnant','lactate','lactating']
    ,'i_protection' : ['trauma','mental']
    ,'i_response_capacity' : ['personnel']
    ,'i_other_infrastructure' : ['communicate','radio','internet']

    ,'i_problem' : ['challenge']
    ,'i_demand_side' : ['need','demand','gap','priority', 'receive'] # note receive implies both supply and demand
    ,'i_supply_side' : ['response','contribute','provide','source','address','deploy','receive'] # note receive implies both supply and demand

    ,'i_assessments' : ['assess','assessment']
}

#some words, particularly verbs, must be in their conjucated form to be useful
#eg. "sourcing" vs "source" has too much potential overlap
#verb_tense_indicators = {
#    'i_supply_side_v' : ['sourcing','providing']
#}

# %%
def find_and_add_indicator(df, indicators):
    ind_counter = []
    for ind in indicators:
  
        df[ind] = df['lower_lemmas'].apply(lambda x: 1 if len([w for w in x if w in indicators[ind]])>0 else 0)
        ind_counter.append(ind)
        #print(ind_counter)
    df['i_count'] = df[ind_counter].sum(axis=1)

    return df

df = find_and_add_indicator(df, indicators)

def declare_primary_record_type(row):

    if row['i_count'] == 0:
        return 'background'
    elif row['i_supply_side']:
        return 'response_details'
    elif row['i_demand_side']:
        return 'demand_side'
    elif row[['i_damage','i_health_infrastructure','i_education_infrastructure']].sum() > 0:
        return 'damage_to_homes_and_infrastructure'
    else:
        return 'other'




df['record_type'] = df.apply(declare_primary_record_type, axis=1)

# %% [markdown]
# ## Now That Indicators Are set - extract more specific details

# %%
def obtain_killed_numeric_value(doc):

    key_values = []
    
    def check_flags(lst):
        for l in lst:
            if l == -1:
                return False
        return True

    #doc = doc.tolist()[0]
    attribute = -1
    noun = -1
    count = -1

    for t in doc:
        if str(t).isdigit():
            count = t
        if t in indicators['i_people']:
            noun = t
        if t in indicators['i_killed']:
            attribute = t

        if check_flags([noun,attribute,count]):

            noun_att_cnt = (noun,attribute,count)
            key_values.append(noun_att_cnt)

            noun = -1
            attribute = -1
            count = -1

    return key_values
            
    
def obtain_injured_numeric_value(doc):

    key_values = []
    
    def check_flags(lst):
        for l in lst:
            if l == -1:
                return False
        return True

    #doc = doc.tolist()[0]
    attribute = -1
    noun = -1
    count = -1

    for t in doc:
        if str(t).isdigit():
            count = t
        if t in indicators['i_people']:
            noun = t
        if t in indicators['i_injured']:
            attribute = t

        if check_flags([noun,attribute,count]):

            noun_att_cnt = (noun,attribute,count)
            key_values.append(noun_att_cnt)

            noun = -1
            attribute = -1
            count = -1

    return key_values

def obtain_counted_noun_chunks(doc):
    counted_things = []
    for x in list(extract.noun_chunks(doc)):
        for token in x:
            if str(token).isdigit():
                counted_things.append(x)
                continue
    if len(counted_things) > 0:
        return counted_things
    else:
        return ''

def obtain_all_entities(doc):
    #stop_ents = STOP_ENTS
    ents = list(extract.entities(doc))
    if len(ents) < 1:
        return None
    entities = defaultdict(list) 
    for e in ents:
        #if e.text not in stop_ents:
        entities[e.label_].append(e)

    return entities   
    

print(obtain_killed_numeric_value(df['wo_parens_lower_lemmas'][df['i_killed'] == 1].tolist()[0]))
print(obtain_injured_numeric_value(df['wo_parens_lower_lemmas'][df['i_injured'] == 1].tolist()[0]))
# Out:
# [('people', 'kill', '100')]
# [('people', 'injure', '500')]

# %%
df['num_killed'] = df['wo_parens_lower_lemmas'][df['i_killed'] == 1].apply(obtain_killed_numeric_value)
df['num_injured'] = df['wo_parens_lower_lemmas'][df['i_injured'] == 1].apply(obtain_injured_numeric_value)
df['num_others'] = df['spacy_wo_parens'].apply(obtain_counted_noun_chunks)
df['noun_chunks'] = df['spacy_wo_parens'].apply(lambda doc: list(extract.noun_chunks(doc)))
df['entities'] = df['spacy_wo_parens'].apply(obtain_all_entities)

# %%
df[df['i_killed'] == 1]
# Out:
#   report_date  source                                           filename  \
# 4  2023-10-13  UNOCHA  D://projects//_external_files//surveyor//Herat...
#
#    sent_idx                                    string_sentence  \
# 4         4  Initial assessments indicate that as many as 1...
#
#                                            spacy_doc  \
# 4  (Initial, assessments, indicate, that, as, man...
#
#                                         lower_lemmas  \
# 4  [initial, assessment, indicate, that, as, many...
#
#                                string_sent_wo_parens  \
# 4  Initial assessments indicate that as many as 1...
#
#                                      spacy_wo_parens  \
# 4  (Initial, assessments, indicate, that, as, man...
#
#                               wo_parens_lower_lemmas  ... i_demand_side  \
# 4  [initial, assessment, indicate, that, as, many...  ...             0
#
#   i_supply_side i_assessments  i_count  record_type             num_killed  \
# 4             0             1        4        other  [(people, kill, 100)]
#
#                num_injured                                         num_others  \
# 4  [(people, injure, 500)]  [(as, many, as, 100,  , people), (8, villages)...
#
#                                          noun_chunks  \
# 4  [(Initial, assessments), (as, many, as, 100,  ...
#
#                                             entities
# 4  {'CARDINAL': [(as, many, as, 100), (8), (500),...
#
# [1 rows x 40 columns]

# %%
df.to_csv("c://temp//proc.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.to_csv("c://temp//proc.csv")
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\io\common.py:420, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     415     pass
#     417 try:
#     418     file_obj = fsspec.open(
#     419         filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
# --> 420     ).open()
#     421 # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#     422 except tuple(err_types_to_retry_with_anon):
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\core.py:132, in OpenFile.open(self)
#     125 def open(self):
#     126     """Materialise this as a real open file without context
#     127
#     128     The OpenFile object should be explicitly closed to avoid enclosed file
#     129     instances persisting. You must, therefore, keep a reference to the OpenFile
#     130     during the life of the file-like it generates.
#     131     """
# --> 132     return self.__enter__()
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\core.py:100, in OpenFile.__enter__(self)
#      97 def __enter__(self):
#      98     mode = self.mode.replace("t", "").replace("b", "") + "b"
# --> 100     f = self.fs.open(self.path, mode=mode)
#     102     self.fobjects = [f]
#     104     if self.compression is not None:
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\spec.py:1309, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1307 else:
#    1308     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1309     f = self._open(
#    1310         path,
#    1311         mode=mode,
#    1312         block_size=block_size,
#    1313         autocommit=ac,
#    1314         cache_options=cache_options,
#    1315         **kwargs,
#    1316     )
#    1317     if compression is not None:
#    1318         from fsspec.compression import compr
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\implementations\local.py:180, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     178 if self.auto_mkdir and "w" in mode:
#     179     self.makedirs(self._parent(path), exist_ok=True)
# --> 180 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\implementations\local.py:298, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     296 self.compression = get_compression(path, compression)
#     297 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 298 self._open()
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\fsspec\implementations\local.py:303, in LocalFileOpener._open(self)
#     301 if self.f is None or self.f.closed:
#     302     if self.autocommit or "w" not in self.mode:
# --> 303         self.f = open(self.path, mode=self.mode)
#     304         if self.compression:
#     305             compress = compr[self.compression]
#
# PermissionError: [Errno 13] Permission denied: 'c:/temp/proc.csv'

# %% [markdown]
# # Main DF Built... now do more processing

# %%
def extract_entities(row):
    entities = row['entities']
    if entities is None:
        return ''
    en=[]
    for label in entities:
        for e in entities.get(label):
            ent = ' '.join([w.text for w in e]).strip()
            en.append([label,ent])
            
    return en
    #else:
    #    return ''


def extract_ncs(row):
    #data type, list of spans
    xs = row['noun_chunks']
    if xs is None:
        return ''
    en=[]

    for e in xs:
        ent = ' '.join([w.text for w in e]).strip()
        en.append(['NOUN_CHUNK',ent])
    return en


def extract_numeric_key_values(row):
    #data type, list of spans
    xs = row['num_others']
    if xs is None:
        return ''
    return_list=[]

    for e in xs:
        prefix = ''
        numeric = ''
        suffix = ''

        for token in e:
            if token.is_alpha == False:
                numeric = token.text
            elif numeric == '': #alpha but numeric not set yet, this is prefix
                prefix = prefix + ' ' + token.text
            else:
                suffix = suffix + ' ' + token.text
        
        return_list.append([prefix.strip(),numeric,suffix.strip()])   
        
    return return_list


def split_key_value_in_df(field,delim=','):

    s = pd.Series({'prefix' : field, 'left_label' : field, 'right_label' : field})
    
    if isinstance(field, list):
        fields = field
    elif isinstance(field, str):
        fields = field.split(delim)
    else:
        print(field)
    
     
    if len(fields) == 2:
        s = pd.Series({'prefix' : '', 'left_label' : fields[0], 'right_label' : fields[1]})
    elif len(fields) == 3:
        s = pd.Series({'prefix' : fields[0], 'left_label' : fields[1], 'right_label' : fields[2]})



    return s

def split_key_value_in_df_orig(field,left_label="d",right_label="f",delim=','):

    s = pd.Series({left_label : field, right_label : field})
    
    if isinstance(field, list):
     
        if len(field) == 2:
            s = pd.Series({left_label : field[0], right_label : field[1]})

    elif isinstance(field, str):
        fields = field.split(delim)
        if len(fields) == 2:
            s = pd.Series({left_label : fields[0], right_label : fields[1]})

    return s

# %%
df[['filename','sent_idx','string_sentence','noun_chunks']][df['noun_chunks'].isna() == False]
# Out:
#                                              filename  sent_idx  \
# 0   D://projects//_external_files//surveyor//Herat...         0
# 1   D://projects//_external_files//surveyor//Herat...         1
# 2   D://projects//_external_files//surveyor//Herat...         2
# 3   D://projects//_external_files//surveyor//Herat...         3
# 4   D://projects//_external_files//surveyor//Herat...         4
# 5   D://projects//_external_files//surveyor//Herat...         5
# 6   D://projects//_external_files//surveyor//Herat...         6
# 7   D://projects//_external_files//surveyor//Herat...         7
# 8   D://projects//_external_files//surveyor//Herat...         8
# 9   D://projects//_external_files//surveyor//Herat...         9
# 10  D://projects//_external_files//surveyor//Herat...        10
# 11  D://projects//_external_files//surveyor//Herat...        11
# 12  D://projects//_external_files//surveyor//Herat...        12
# 13  D://projects//_external_files//surveyor//Herat...        13
# 14  D://projects//_external_files//surveyor//Herat...        14
# 15  D://projects//_external_files//surveyor//Herat...        15
# 16  D://projects//_external_files//surveyor//Herat...        16
# 17  D://projects//_external_files//surveyor//Herat...        17
# 18  D://projects//_external_files//surveyor//Herat...        18
# 19  D://projects//_external_files//surveyor//Herat...        19
# 20  D://projects//_external_files//surveyor//Herat...        20
# 21  D://projects//_external_files//surveyor//Herat...        21
# 22  D://projects//_external_files//surveyor//Herat...        22
# 23  D://projects//_external_files//surveyor//Herat...        23
# 24  D://projects//_external_files//surveyor//Herat...        24
# 25  D://projects//_external_files//surveyor//Herat...        25
# 26  D://projects//_external_files//surveyor//Herat...        26
#
#                                       string_sentence  \
# 0          Highlights  On 7 October 2023 at around 11
# 1                                  00 local time, a 6
# 2   3  magnitude earthquake struck 40km west of He...
# 3   Several  aftershocks have occurred since, with...
# 4   Initial assessments indicate that as many as 1...
# 5   Additionally, 465  houses are reported to have...
# 6   In total, 4200 people (600 families) are asses...
# 7   Mahal Wadakah is understood to be  the worst a...
# 8   Additionally, an estimated 300 families (2100 ...
# 9   Partners and local authorities anticipate the ...
# 10  In response, humanitarian partners have initia...
# 11  Ongoing priority needs include ESNFIs, food as...
# 12  Humanitarian Needs and Response Humanitarian p...
# 13  To date, 200 people are understood to be recei...
# 14  IOM and UNHCR will also provide emergency shel...
# 15                                WFP will dispatch 2
# 16  1kg of highenergy biscuits for 710 affected ho...
# 17  Acute Watery Diarrhoea outbreaks are of partic...
# 18  The Red Cross and Red Crescent have also mobil...
# 19  Afghanistan Flash Update 1 Earthquake in Herat...
# 20  00) 22 June 2022 As of 28 July 2021 OCHA Afgha...
# 21                                             unocha
# 22  org Coordination OCHA is coordinating the emer...
# 23  A meeting was  also held with the Provincial G...
# 24  To date, IOM has deployed 4 assessment teams t...
# 25  REACH has also provided a households multisect...
# 26
#
#                                           noun_chunks
# 0                        [(Highlights), (7, October)]
# 1                                 [(00, local, time)]
# 2   [(3,  , magnitude, earthquake), (Herat,  , Cit...
# 3   [(Several,  , aftershocks), (initial,  , quake...
# 4   [(Initial, assessments), (as, many, as, 100,  ...
# 5                                  [(465,  , houses)]
# 6              [(4200, people), (date), (1400, IDPs)]
# 7      [(Mahal, Wadakah), (worst, affected, village)]
# 8   [(estimated, 300, families), (Herat, City), (t...
# 9   [(Partners), (local, authorities), (number), (...
# 10  [(response), (humanitarian, partners), (relief...
# 11  [(Ongoing, priority, needs), (ESNFIs), (food, ...
# 12  [(Humanitarian, Needs, and, Response, Humanita...
# 13  [(date), (200, people), (emergency, trauma, ca...
# 14  [(IOM), (UNHCR), (emergency, shelter, support)...
# 15                                            [(WFP)]
# 16  [(highenergy, biscuits), (710, affected, house...
# 17  [(Acute, Watery, Diarrhoea, outbreaks), (parti...
# 18  [(Red, Cross), (Red, Crescent), (response, tea...
# 19  [(Afghanistan, Flash, Update, 1, Earthquake), ...
# 20  [(July, 2021, OCHA, Afghanistan,  , 2, United,...
# 21                                         [(unocha)]
# 22  [(org, Coordination, OCHA), (emergency, respon...
# 23  [(meeting), (Provincial, Governor), (OCHA, Her...
# 24  [(date), (IOM), (4, assessment, teams), (that)...
# 25  [(REACH), (households, multisector, rapid, ass...
# 26                                                 []

# %%
#use this as a repeatable-ish pattern for expanding on all the qualitative fields
df_entities = df[['filename','sent_idx','string_sentence','entities']][df['entities'].isna() == False].copy()
df_entities['tmp'] = df_entities.apply(extract_entities, axis=1)
df_entities = df_entities.drop(columns=['entities'])
df_entities = df_entities.explode('tmp')
df_entities['rec_type'] = 'ENTITY'
df_entities[['rec_prefix','rec_key','rec_value']] = df_entities.apply(lambda x: split_key_value_in_df(x.tmp), axis=1)

#now noun_chunks
df_nouns = df[['filename','sent_idx','string_sentence','noun_chunks']][df['noun_chunks'].isna() == False].copy()
df_nouns['tmp'] = df_nouns.apply(extract_ncs, axis=1)
#df_nouns = df_nouns.drop(columns=['noun_chunks'])
df_nouns = df_nouns.explode('tmp')
df_nouns['rec_type'] = 'NOUN_SEQUENCE'
df_nouns = df_nouns[df_nouns['tmp'].isna() == False].copy()
df_nouns[['rec_prefix','rec_key','rec_value']] = df_nouns.apply(lambda x: split_key_value_in_df(x.tmp), axis=1)

# %%
df_quants = df[['filename','sent_idx','string_sentence','num_others']][df['num_others'] != ''].copy()
df_quants['tmp'] = df_quants.apply(extract_numeric_key_values, axis=1)
df_quants = df_quants.drop(columns=['num_others'])
df_quants = df_quants.explode('tmp')
df_quants['rec_type'] = 'QUANTIFIED_NOUN'
df_quants[['rec_prefix','rec_key','rec_value']] = df_quants.apply(lambda x: split_key_value_in_df(x.tmp), axis=1)
df_quants


#num_others
# Out:
#                                              filename  sent_idx  \
# 0   D://projects//_external_files//surveyor//Herat...         0
# 1   D://projects//_external_files//surveyor//Herat...         1
# 2   D://projects//_external_files//surveyor//Herat...         2
# 4   D://projects//_external_files//surveyor//Herat...         4
# 4   D://projects//_external_files//surveyor//Herat...         4
# 4   D://projects//_external_files//surveyor//Herat...         4
# 4   D://projects//_external_files//surveyor//Herat...         4
# 5   D://projects//_external_files//surveyor//Herat...         5
# 6   D://projects//_external_files//surveyor//Herat...         6
# 6   D://projects//_external_files//surveyor//Herat...         6
# 8   D://projects//_external_files//surveyor//Herat...         8
# 12  D://projects//_external_files//surveyor//Herat...        12
# 13  D://projects//_external_files//surveyor//Herat...        13
# 13  D://projects//_external_files//surveyor//Herat...        13
# 13  D://projects//_external_files//surveyor//Herat...        13
# 14  D://projects//_external_files//surveyor//Herat...        14
# 14  D://projects//_external_files//surveyor//Herat...        14
# 16  D://projects//_external_files//surveyor//Herat...        16
# 16  D://projects//_external_files//surveyor//Herat...        16
# 16  D://projects//_external_files//surveyor//Herat...        16
# 19  D://projects//_external_files//surveyor//Herat...        19
# 20  D://projects//_external_files//surveyor//Herat...        20
# 20  D://projects//_external_files//surveyor//Herat...        20
# 22  D://projects//_external_files//surveyor//Herat...        22
# 22  D://projects//_external_files//surveyor//Herat...        22
# 24  D://projects//_external_files//surveyor//Herat...        24
#
#                                       string_sentence  \
# 0          Highlights  On 7 October 2023 at around 11
# 1                                  00 local time, a 6
# 2   3  magnitude earthquake struck 40km west of He...
# 4   Initial assessments indicate that as many as 1...
# 4   Initial assessments indicate that as many as 1...
# 4   Initial assessments indicate that as many as 1...
# 4   Initial assessments indicate that as many as 1...
# 5   Additionally, 465  houses are reported to have...
# 6   In total, 4200 people (600 families) are asses...
# 6   In total, 4200 people (600 families) are asses...
# 8   Additionally, an estimated 300 families (2100 ...
# 12  Humanitarian Needs and Response Humanitarian p...
# 13  To date, 200 people are understood to be recei...
# 13  To date, 200 people are understood to be recei...
# 13  To date, 200 people are understood to be recei...
# 14  IOM and UNHCR will also provide emergency shel...
# 14  IOM and UNHCR will also provide emergency shel...
# 16  1kg of highenergy biscuits for 710 affected ho...
# 16  1kg of highenergy biscuits for 710 affected ho...
# 16  1kg of highenergy biscuits for 710 affected ho...
# 19  Afghanistan Flash Update 1 Earthquake in Herat...
# 20  00) 22 June 2022 As of 28 July 2021 OCHA Afgha...
# 20  00) 22 June 2022 As of 28 July 2021 OCHA Afgha...
# 22  org Coordination OCHA is coordinating the emer...
# 22  org Coordination OCHA is coordinating the emer...
# 24  To date, IOM has deployed 4 assessment teams t...
#
#                                                   tmp         rec_type  \
# 0                                      [, 7, October]  QUANTIFIED_NOUN
# 1                                  [, 00, local time]  QUANTIFIED_NOUN
# 2                         [,  , magnitude earthquake]  QUANTIFIED_NOUN
# 4                             [as many as,  , people]  QUANTIFIED_NOUN
# 4                                     [, 8, villages]  QUANTIFIED_NOUN
# 4                              [further, 500, people]  QUANTIFIED_NOUN
# 4                            [closer to, 320, people]  QUANTIFIED_NOUN
# 5                                       [,  , houses]  QUANTIFIED_NOUN
# 6                                    [, 4200, people]  QUANTIFIED_NOUN
# 6                                      [, 1400, IDPs]  QUANTIFIED_NOUN
# 8                          [estimated, 300, families]  QUANTIFIED_NOUN
# 12                  [, 5, emergency assessment teams]  QUANTIFIED_NOUN
# 13                                    [, 200, people]  QUANTIFIED_NOUN
# 13                                 [, 3, trauma kits]  QUANTIFIED_NOUN
# 13                                 [, 150, surgeries]  QUANTIFIED_NOUN
# 14                                  [, 700, families]  QUANTIFIED_NOUN
# 14                              [, 640, family tents]  QUANTIFIED_NOUN
# 16                       [, 710, affected households]  QUANTIFIED_NOUN
# 16                             [, 1300, dignity kits]  QUANTIFIED_NOUN
# 16                                     [, 8, October]  QUANTIFIED_NOUN
# 19          [Afghanistan Flash Update, 1, Earthquake]  QUANTIFIED_NOUN
# 20  [July, 2, OCHA Afghanistan United Nations Office]  QUANTIFIED_NOUN
# 20  [July, 2, OCHA Afghanistan United Nations Office]  QUANTIFIED_NOUN
# 22                                     [, 7, October]  QUANTIFIED_NOUN
# 22                                     [, 8, October]  QUANTIFIED_NOUN
# 24                            [, 4, assessment teams]  QUANTIFIED_NOUN
#
#                   rec_prefix rec_key                               rec_value
# 0                                  7                                 October
# 1                                 00                              local time
# 2                                                       magnitude earthquake
# 4                 as many as                                          people
# 4                                  8                                villages
# 4                    further     500                                  people
# 4                  closer to     320                                  people
# 5                                                                     houses
# 6                               4200                                  people
# 6                               1400                                    IDPs
# 8                  estimated     300                                families
# 12                                 5              emergency assessment teams
# 13                               200                                  people
# 13                                 3                             trauma kits
# 13                               150                               surgeries
# 14                               700                                families
# 14                               640                            family tents
# 16                               710                     affected households
# 16                              1300                            dignity kits
# 16                                 8                                 October
# 19  Afghanistan Flash Update       1                              Earthquake
# 20                      July       2  OCHA Afghanistan United Nations Office
# 20                      July       2  OCHA Afghanistan United Nations Office
# 22                                 7                                 October
# 22                                 8                                 October
# 24                                 4                        assessment teams

# %%
idx=5
print(list(set(df_entities['string_sentence'][df_entities['sent_idx'] == idx].tolist())))
df_entities[df_entities['sent_idx'] == idx]
# Out:
# ['Additionally, 465  houses are reported to have been destroyed and  135 damaged']
#                                             filename  sent_idx  \
# 5  D://projects//_external_files//surveyor//Herat...         5
# 5  D://projects//_external_files//surveyor//Herat...         5
#
#                                      string_sentence              tmp  \
# 5  Additionally, 465  houses are reported to have...  [CARDINAL, 465]
# 5  Additionally, 465  houses are reported to have...  [CARDINAL, 135]
#
#   rec_type rec_prefix   rec_key rec_value
# 5   ENTITY             CARDINAL       465
# 5   ENTITY             CARDINAL       135

# %%
df_nouns[df_nouns['sent_idx'] == idx]
# Out:
#                                             filename  sent_idx  \
# 5  D://projects//_external_files//surveyor//Herat...         5
#
#                                      string_sentence         noun_chunks  \
# 5  Additionally, 465  houses are reported to have...  [(465,  , houses)]
#
#                           tmp       rec_type rec_prefix     rec_key  \
# 5  [NOUN_CHUNK, 465   houses]  NOUN_SEQUENCE             NOUN_CHUNK
#
#       rec_value
# 5  465   houses

# %%
df_quants[df_quants['sent_idx'] == idx]
# Out:
#                                             filename  sent_idx  \
# 5  D://projects//_external_files//surveyor//Herat...         5
#
#                                      string_sentence            tmp  \
# 5  Additionally, 465  houses are reported to have...  [,  , houses]
#
#           rec_type rec_prefix rec_key rec_value
# 5  QUANTIFIED_NOUN                       houses

# %% [markdown]
# # End

# %%
#df_org_details = df[['filename','sent_idx','string_sentence','spacy_doc','entities']].copy()
#df_org_details['organization'] = df['entities'].apply(extract_orgs)
#df_org_details = df_org_details.drop(columns=['entities'])
#df_org_details = df_org_details.explode('organization')

#unique_orgs = list(set(df_org_details['organization'].tolist()))

#df_org_details['spacy_doc'][df_org_details['organization'] == 'UNHCR'].tolist()

# %%
def extract_kwic(doc, keyword):
    triple = list(extract.keyword_in_context(doc, keyword, window_width = 80,))

    prefix = ''
    keyword = ''
    suffix = ''
    #print(triple)
    if len(triple) == 1:
        prefix = triple[0][0]
        keyword = triple[0][1]
        suffix = triple[0][2]
    return pd.Series({'prefix':prefix,'keyword':keyword,'suffix':suffix})
    

keyword = 'UNHCR'
df_org_details[['prefix','keyword','suffix']] = df_org_details['spacy_doc'].apply(lambda x: extract_kwic(x, keyword))

# %%
df_org_details[df_org_details['keyword'] != '']
# Out:
#                                              filename  sent_idx  \
# 32  D://projects//_external_files//surveyor//Herat...        32
# 36  D://projects//_external_files//surveyor//Herat...        36
# 38  D://projects//_external_files//surveyor//Herat...        38
# 87  D://projects//_external_files//surveyor//Herat...        87
#
#                                       string_sentence  \
# 32  ESNFI Cluster partners IOM, UNHCR, and UNICEF ...
# 36  In coordination with the Shelter Cluster, UNHC...
# 38  UNHCR and its partners are expected to start t...
# 87  UNHCR has distributed solar lamps and hygiene ...
#
#                                             spacy_doc  \
# 32  (ESNFI, Cluster, partners, IOM, ,, UNHCR, ,, a...
# 36  (In, coordination, with, the, Shelter, Cluster...
# 38  (UNHCR, and, its, partners, are, expected, to,...
# 87  (UNHCR, has, distributed, solar, lamps, and, h...
#
#                                              entities  \
# 32  {'ORG': [(ESNFI, Cluster), (IOM), (UNHCR), (UN...
# 36  {'ORG': [(Shelter, Cluster), (UNHCR), (Health,...
# 38  {'ORG': [(UNHCR)], 'DATE': [(tomorrow)], 'FAC'...
# 87                                 {'ORG': [(UNHCR)]}
#
#                                         prefix keyword  \
# 32                ESNFI Cluster partners IOM,    UNHCR
# 36  In coordination with the Shelter Cluster,    UNHCR
# 38                                               UNHCR
# 87                                               UNHCR
#
#                                                suffix
# 32  , and UNICEF  have delivered emergency relief ...
# 36   contributed 100 refugee housing units and 100...
# 38   and its partners are expected to start the as...
# 87   has distributed solar lamps and hygiene kits,...

# %%
kwic = list(extract.keyword_in_context(full_doc, 'UNHCR', window_width = 80,))
kwic
# Out:
# [('nvolved and supporting community level assessments. ESNFI Cluster partners IOM, ',
#   'UNHCR',
#   ', and UNICEF  have delivered emergency relief assistance, including emergency sh'),
#  ('er clothing kits, and solar modules.  In coordination with the Shelter Cluster, ',
#   'UNHCR',
#   ' contributed 100 refugee housing units and 100 blankets to  the Health Cluster, '),
#  ('nse. The units are to be set up at the health centres to  accommodate patients. ',
#   'UNHCR',
#   ' and its partners are expected to start the assembly of the units tomorrow, at  '),
#  (' PFA, psychosocial counselling, psychiatry  services, and medicine to patients. ',
#   'UNHCR',
#   ' has distributed solar lamps and hygiene kits, among other critical supplies, an')]
